# %%
Nt= 1.0
r= 1.5
K= 100
T= 30
print("0"+"\t"+str(Nt))
for i in range(T):
    Nt= Nt + r * Nt*(1.0-Nt/K)
    print(str(i+1)+"\t"+str(Nt))
# Out:
# 0	1.0
# 1	2.485
# 2	6.119871625
# 3	14.737886631902798
# 4	33.58663704413471
# 5	67.04565979132015
# 6	100.18734202549874
# 7	99.90580253173287
# 8	100.04696563668814
# 9	99.9764840950905
# 10	100.011749657488
# 11	99.99412310043923
# 12	100.00293793171116
# 13	99.99853090467279
# 14	100.00073451528999
# 15	99.99963273426232
# 16	100.00018363084557
# 17	99.9999081840714
# 18	100.00004590783784
# 19	99.99997704604947
# 20	100.00001147696736
# 21	99.99999426151435
# 22	100.00000286924234
# 23	99.99999856537872
# 24	100.0000007173106
# 25	99.9999996413447
# 26	100.00000017932764
# 27	99.99999991033619
# 28	100.0000000448319
# 29	99.99999997758404
# 30	100.00000001120797

# %%
import matplotlib.pyplot as plt

# %%
Nt= 1.0
r= 1.5
K= 100
T= 30
dataX=[]
dataY=[]
dataX.append(0)
dataY.append(Nt)
for i in range(T):
    Nt= Nt + r * Nt*(1.0-Nt/K)
    dataX.append(i+1)
    dataY.append(Nt)

# %%
plt.plot(dataX, dataY)
plt.xlabel("time")
plt.ylabel("population size")
plt.show()

# %%
import matplotlib.pyplot as plt
 
#図の大きさとフォントサイズを設定
plt.rcParams["font.size"] = 20
plt.rcParams['figure.figsize'] = 12,10 
def do_logistic_growth(k, r, n0, t):
    nt= n0
    datax=[]
    datay=[]
 
    datax.append(0)
    datay.append(nt)
 
    for i in range(t):
        nt= nt+r*nt*(1.0-nt/k)
        datax.append(i+1)
        datay.append(nt)
 
    return(datax, datay)
 
 
dataX, dataY= do_logistic_growth(100.0, 1.5, 1.0, 300)
plt.plot(dataX, dataY)
 
plt.xlabel("time")
plt.ylabel("population size")
plt.show()

# %%
# dataX, dataY= do_logistic_growth(100.0,0, 1.0, 20)
# plt.plot(dataX, dataY)
# dataX, dataY= do_logistic_growth(100.0,1, 1.0, 20)
# plt.plot(dataX, dataY)
dataX, dataY= do_logistic_growth(100.0,2, 1.0, 20)
plt.plot(dataX, dataY)
dataX, dataY= do_logistic_growth(100.0,2.5, 1.0, 20)
plt.plot(dataX, dataY)
dataX, dataY= do_logistic_growth(100.0,3, 1.0, 20)
plt.plot(dataX, dataY)
 
plt.xlabel("time")
plt.ylabel("population size")
plt.show()

# %%
import matplotlib.pyplot as plt
 
#図の大きさとフォントサイズを設定
plt.rcParams["font.size"] = 20
plt.rcParams['figure.figsize'] = 12,10 
def do_logistic_growth(k, r, n0, t):
    nt= n0
    datax=[]
    datay=[]
 
    datax.append(0)
    datay.append(nt)
 
    for i in range(t):
        nt= nt+r*nt*(1.0-nt/k)
        datax.append(i+1)
        datay.append(nt)
 
    return(datax, datay)
lis = [i/100 for i in range(0,300,1)]
for i in lis:
    dataX, dataY= do_logistic_growth(100.0,i , 1.0, 20)
    plt.plot(dataX, dataY,label=str(i))
    plt.title(str(i))
    plt.xlabel("time")
    plt.ylabel("population size")
    plt.show()

# %%
import matplotlib.pyplot as plt
 
#図の大きさとフォントサイズを設定
plt.rcParams["font.size"] = 20
plt.rcParams['figure.figsize'] = 12,10 
def do_logistic_growth(k, r, n0, t):
    nt= n0
    datax=[]
    datay=[]
 
    datax.append(0)
    datay.append(nt)
 
    for i in range(t):
        nt= nt+r*nt*(1.0-nt/k)
        datax.append(i+1)
        datay.append(nt)
 
    return(datax, datay)
 
 
dataX, dataY= do_logistic_growth(100.0, 2.80, 1.0, 40)
plt.plot(dataX, dataY)
 
plt.xlabel("time")
plt.ylabel("population size")
plt.show()

# %%
import matplotlib.pyplot as plt
 
#図の大きさとフォントサイズを設定
plt.rcParams["font.size"] = 20
plt.rcParams['figure.figsize'] = 12,10 
def do_logistic_growth(k, r, n0, t):
    nt= n0
    datax=[]
    datay=[]
 
    datax.append(0)
    datay.append(nt)
 
    for i in range(t):
        nt= nt+r*nt*(1.0-nt/k)
        datax.append(i+1)
        datay.append(nt)
 
    return(datax, datay)
 
 
dataX, dataY= do_logistic_growth(100.0, 1.94, 1.0, 20)
plt.plot(dataX, dataY)
 
plt.xlabel("time")
plt.ylabel("population size")
plt.show()

# %%
# 課題提出用
import matplotlib.pyplot as plt
 
#図の大きさとフォントサイズを設定
plt.rcParams["font.size"] = 20
plt.rcParams['figure.figsize'] = 12,10 
def do_logistic_growth(k, r, n0, t):
    nt= n0
    datax=[]
    datay=[]
 
    datax.append(0)
    datay.append(nt)
 
    for i in range(t):
        nt= nt+r*nt*(1.0-nt/k)
        datax.append(i+1)
        datay.append(nt)
 
    return(datax, datay)
dataX, dataY= do_logistic_growth(100.0, 1.88 , 1.0, 20)
plt.plot(dataX, dataY,label=str(i))
dataX, dataY= do_logistic_growth(100.0, 1.96 , 1.0, 20)
plt.plot(dataX, dataY,label=str(i))
dataX, dataY= do_logistic_growth(100.0, 2.74 , 1.0, 20)
plt.plot(dataX, dataY)
plt.xlabel("time")
plt.ylabel("population size")
plt.show()
